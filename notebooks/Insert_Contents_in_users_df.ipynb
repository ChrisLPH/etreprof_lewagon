# %% [markdown]
# # Import contents usage in users df

# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime
from tqdm import tqdm

# %% [markdown]
# ## Import and clean contents

# %%
df_contents = pd.read_csv("../raw_data/contents.csv", low_memory = False)

# %%
df_contents.columns
# Out:
# Index(['id', 'title', 'type', 'markdown', 'categories', 'niveaux', 'auteur',
#        'categorie', 'categorie_principale', 'created_at', 'date_debut',
#        'description', 'difficulte', 'downloads_count', 'duree_heures',
#        'duree_minutes', 'duree_secondes', 'etat', 'json_categories',
#        'json_centre_interet', 'json_niveau', 'json_niveau_detail',
#        'landing_url', 'nb_abonnes', 'nb_commentaires', 'nb_presents', 'niveau',
#        'page_view_count', 'published_at', 'score_downvote', 'score_upvote',
#        'source_url', 'sous_categorie', 'statut', 'titre', 'updated_at', 'url',
#        'transition_ecologique', 'sante_mentale', 'ecole_inclusive', 'cps',
#        'reussite_tous_eleves'],
#       dtype='object')

# %%
df_contents.shape
# Out:
# (4898, 42)

# %%
df_contents = df_contents[(df_contents.markdown.str.len() > 5) & (df_contents.type.isin(['article',
 'guide_pratique', 'fiche_outils', 'contenu']) ) & (df_contents.markdown.notna())]

# %%
df_contents.shape
# Out:
# (1416, 42)

# %%
df_contents_lite = df_contents[['id', 'type', 'transition_ecologique', 'sante_mentale', 'ecole_inclusive', 'cps',
       'reussite_tous_eleves']]

# %%
df_contents_lite.columns
# Out:
# Index(['id', 'type', 'transition_ecologique', 'sante_mentale',
#        'ecole_inclusive', 'cps', 'reussite_tous_eleves'],
#       dtype='object')

# %%
df_contents_lite['master_theme'] = None
# Out:
# /tmp/ipykernel_666093/3568060577.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_contents_lite['master_theme'] = None

# %%
df_contents_lite.columns
# Out:
# Index(['id', 'type', 'transition_ecologique', 'sante_mentale',
#        'ecole_inclusive', 'cps', 'reussite_tous_eleves', 'master_theme'],
#       dtype='object')

# %% [markdown]
# ## Import `interactions` to map contents with users

# %% [markdown]
# ### Import of database

# %%
df_interactions = pd.read_csv('../raw_data/interaction_events.csv', low_memory=False)

# %%
df_interactions.shape
# Out:
# (16675373, 11)

# %% [markdown]
# ### Explore database

# %%
df_interactions.columns
# Out:
# Index(['id', 'user_id', 'type', 'content_type', 'content_id', 'context_type',
#        'context_id', 'thema_prio', 'url', 'created_at', 'updated_at'],
#       dtype='object')

# %%
df_interactions.type.unique()
# Out:
# array(['click', 'subscription-ended', 'subscribed',
#        'subscription-completed', 'submitted', 'attended', 'download',
#        'session', 'connexion', 'inscription', 'contenu_vote',
#        'contenu_favoris', 'comment_posted', 'register', 'completed',
#        'page_view', 'opened_mail', 'click_mail'], dtype=object)

# %%
df_interactions.sample(30)
# Out:
#                 id  user_id         type      content_type  content_id  \
# 3013141   12043624    36166  opened_mail        onboarding  36dfa826b3
# 13477047  22507600   107000  opened_mail  infolettre_hebdo  7422513d98
# 5703213   14733696    76702  opened_mail        onboarding  bc9eacbd79
# 4015944   13046427    48575  opened_mail  infolettre_hebdo  b350c35345
# 8414914   17445397    43709      session       opened_mail  a954c9e011
# 12002464  21032986    46582     download      fiche-outils         540
# 16494112  25528714   130344      session       opened_mail  72764ec12f
# 4762474   13792957    58828  opened_mail  infolettre_hebdo  aba3ead9cf
# 823961     9854444     2301      session       opened_mail  7b70823d83
# 14434245  23467277    49525  opened_mail        onboarding  739abdf426
# 6240150   15270633    90696      session       opened_mail  55361aa0a9
# 9522174   18552677    45780      session       opened_mail  f563e05d2b
# 13479851  22510404   114790  opened_mail  infolettre_hebdo  4f99182e04
# 12134440  21164962    45663      session       opened_mail  09d5cff191
# 936253     9966736     4194  opened_mail  infolettre_hebdo  69a456ec20
# 13977180  23007733    93317  opened_mail  infolettre_hebdo  2b70a0cd15
# 13893653  22924206   200911    page_view           Contenu        4412
# 394847      966780    67259     download    guide-pratique          11
# 15102221  24136819    48015   click_mail  infolettre_hebdo  fb3475b23e
# 12338505  21369052    61483      session       opened_mail  55e6ea9dd5
# 10345138  19375641   155179  opened_mail        onboarding  3e59c1a3ce
# 415125      994866   142676   subscribed           atelier         509
# 13878301  22908854   188656  opened_mail  infolettre_hebdo  a490a6b6bc
# 8953873   17984356    72279      session       opened_mail  ce2eb1586e
# 16104954  25139556   164142      session       opened_mail  bdf4097c97
# 12965008  21995555    80570  opened_mail  infolettre_hebdo  9d9bd6bda4
# 5498357   14528840    71125      session       opened_mail  559ca37887
# 6693147   15723630   102293  opened_mail               kit  4896052ae3
# 3643740   12674223    44207  opened_mail  infolettre_hebdo  560429431e
# 8076993   17107476    49193  opened_mail  infolettre_hebdo  86844054d2
#
#               context_type  context_id thema_prio  \
# 3013141                NaN         NaN        NaN
# 13477047               NaN         NaN        NaN
# 5703213                NaN         NaN        NaN
# 4015944                NaN         NaN        NaN
# 8414914   infolettre_hebdo         NaN        NaN
# 12002464           Contenu      4278.0        NaN
# 16494112        onboarding         NaN        NaN
# 4762474                NaN         NaN        NaN
# 823961    infolettre_hebdo         NaN        NaN
# 14434245               NaN         NaN        NaN
# 6240150   infolettre_hebdo         NaN        NaN
# 9522174   infolettre_hebdo         NaN        NaN
# 13479851               NaN         NaN        NaN
# 12134440  infolettre_hebdo         NaN        NaN
# 936253                 NaN         NaN        NaN
# 13977180               NaN         NaN        NaN
# 13893653         ressource         NaN        NaN
# 394847                 NaN         NaN        NaN
# 15102221               NaN         NaN        NaN
# 12338505  infolettre_hebdo         NaN        NaN
# 10345138               NaN         NaN        NaN
# 415125             Atelier         NaN        NaN
# 13878301               NaN         NaN        NaN
# 8953873   infolettre_hebdo         NaN        NaN
# 16104954  infolettre_hebdo         NaN        NaN
# 12965008               NaN         NaN        NaN
# 5498357   infolettre_hebdo         NaN        NaN
# 6693147                NaN         NaN        NaN
# 3643740                NaN         NaN        NaN
# 8076993                NaN         NaN        NaN
#
#                                                         url  \
# 3013141                Lancement Film ÊtrePROF - 28/09/2022
# 13477047                14/12/24 - ÉLÉMENTAIRE [NEWS_HEBDO]
# 5703213          [ENQUETE_FORMATION_CONTINUE]-MAIL 1-230308
# 4015944               04/06/2022 - ELEMENTAIRE [NEWS_HEBDO]
# 8414914                  06/01/24 - MATERNELLE [NEWS_HEBDO]
# 12002464  /ressources/4278/7-activites-briseglace-pour-u...
# 16494112        [OBSERVATOIRE] BAROMÈTRE IA MAIL 2 - 250521
# 4762474                 17/06/23 - ÉLÉMENTAIRE [NEWS_HEBDO]
# 823961       22/08/23 - ÉLÉMENTAIRE [NEWS_HEBDO] - ATELIERS
# 14434245                           [MARKETING] CPS - 250219
# 6240150                 22/04/23 - ÉLÉMENTAIRE [NEWS_HEBDO]
# 9522174                  23/03/24 - SECONDAIRE [NEWS_HEBDO]
# 13479851                 23/11/24 - SECONDAIRE [NEWS_HEBDO]
# 12134440                 16/08/24 - SECONDAIRE [NEWS_HEBDO]
# 936253                   14/01/23 - SECONDAIRE [NEWS_HEBDO]
# 13977180                 11/01/25 - MATERNELLE [NEWS_HEBDO]
# 13893653  /ressources/4412/organiser-la-cooperation-en-c...
# 394847                                    /guides-pratiques
# 15102221  https://www.youtube.com/watch?v=KA9rOzLxY3I&fe...
# 12338505                 28/09/24 - MATERNELLE [NEWS_HEBDO]
# 10345138  [OBSERVATOIRE] ENQUÊTE ÉCOLE INCLUSIVE 2024 - ...
# 415125    /ateliers/?utm_source=instagram&utm_medium=soc...
# 13878301                18/01/25 - ÉLÉMENTAIRE [NEWS_HEBDO]
# 8953873                  24/02/24 - SECONDAIRE [NEWS_HEBDO]
# 16104954                07/06/25 - ÉLÉMENTAIRE [NEWS_HEBDO]
# 12965008                 09/11/24 - MATERNELLE [NEWS_HEBDO]
# 5498357               10/09/2022 - ELEMENTAIRE [NEWS_HEBDO]
# 6693147   01 -  GERER L'ESPACE CLASSE - KIT GESTION DE C...
# 3643740                  10/06/23 - MATERNELLE [NEWS_HEBDO]
# 8076993                  16/12/23 - MATERNELLE [NEWS_HEBDO]
#
#                    created_at           updated_at
# 3013141   2022-09-28 18:04:28  2023-12-01 00:13:19
# 13477047  2024-12-14 10:00:40  2024-12-15 05:40:50
# 5703213   2023-03-19 17:21:05  2023-12-01 05:10:50
# 4015944   2022-06-04 14:46:05  2023-12-01 01:55:26
# 8414914   2024-01-14 02:48:00  2024-01-20 22:32:30
# 12002464  2024-09-07 11:11:59                  NaN
# 16494112  2025-06-28 10:49:11  2025-06-29 10:59:04
# 4762474   2023-06-18 22:01:07  2023-12-01 03:15:34
# 823961    2023-08-22 12:44:42  2023-11-30 20:11:36
# 14434245  2025-02-23 15:58:38  2025-03-02 01:08:05
# 6240150   2023-04-22 11:48:46  2023-12-01 06:27:19
# 9522174   2024-03-24 01:14:15  2024-03-30 23:19:13
# 13479851  2024-12-10 10:07:40  2024-12-15 06:23:38
# 12134440  2024-09-08 21:47:08  2024-09-15 01:01:53
# 936253    2023-01-14 11:20:09  2023-11-30 20:24:33
# 13977180  2025-01-25 12:55:59  2025-01-26 05:34:06
# 13893653  2025-01-24 10:14:23                  NaN
# 394847    2023-06-25 16:13:40                  NaN
# 15102221  2025-04-12 10:44:21  2025-04-13 00:46:29
# 12338505  2024-09-28 22:42:36  2024-09-29 03:17:42
# 10345138  2024-05-25 13:45:10  2024-05-26 10:01:52
# 415125    2023-07-12 21:46:20                  NaN
# 13878301  2025-01-18 10:14:20  2025-01-19 13:42:30
# 8953873   2024-02-24 12:51:58  2024-02-25 01:23:29
# 16104954  2025-06-07 10:40:54  2025-06-08 13:58:07
# 12965008  2024-11-09 12:12:26  2024-11-10 03:35:17
# 5498357   2022-09-10 20:05:26  2023-12-01 04:40:29
# 6693147   2022-10-29 16:49:43  2023-12-01 07:33:29
# 3643740   2023-06-11 15:12:09  2023-12-01 01:18:05
# 8076993   2023-12-16 17:15:34  2023-12-16 22:50:39

# %%
df_interactions[df_interactions.content_id == "4840"]
# Out:
#                 id  user_id          type content_type content_id  \
# 10551507  19582011       68     page_view      Contenu       4840
# 10551512  19582016       68     page_view      Contenu       4840
# 10551513  19582017       68     page_view      Contenu       4840
# 10551717  19582221       68  contenu_vote      Contenu       4840
# 10553226  19583730    20179     page_view      Contenu       4840
# ...            ...      ...           ...          ...        ...
# 16673185  25707787   107935     page_view      Contenu       4840
# 16674140  25708742    33768     page_view      Contenu       4840
# 16674364  25708966   143133     page_view      Contenu       4840
# 16674365  25708967   143133       session      Contenu       4840
# 16674744  25709346   151764     page_view      Contenu       4840
#
#          context_type  context_id thema_prio  \
# 10551507      article         NaN        NaN
# 10551512      article         NaN        NaN
# 10551513      article         NaN        NaN
# 10551717      article         NaN        NaN
# 10553226      article         NaN        NaN
# ...               ...         ...        ...
# 16673185      article         NaN        NaN
# 16674140      article         NaN        NaN
# 16674364      article         NaN        NaN
# 16674365      article         NaN        NaN
# 16674744      article         NaN        NaN
#
#                                                         url  \
# 10551507  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# 10551512  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# 10551513  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# 10551717  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# 10553226  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# ...                                                     ...
# 16673185  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# 16674140  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# 16674364  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# 16674365  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
# 16674744  /ressources/4840/6-facons-dutiliser-l-ia-dans-...
#
#                    created_at updated_at
# 10551507  2024-06-10 11:25:35        NaN
# 10551512  2024-06-10 11:29:38        NaN
# 10551513  2024-06-10 11:29:47        NaN
# 10551717  2024-06-10 14:08:20        NaN
# 10553226  2024-06-11 07:37:06        NaN
# ...                       ...        ...
# 16673185  2025-07-10 11:30:02        NaN
# 16674140  2025-07-10 13:06:04        NaN
# 16674364  2025-07-10 13:49:05        NaN
# 16674365  2025-07-10 13:49:06        NaN
# 16674744  2025-07-10 14:24:21        NaN
#
# [5670 rows x 11 columns]

# %%
df =pd.DataFrame(df_interactions.content_type.value_counts())

# %%
df
# Out:
#                                  content_type
# opened_mail                           6217444
# infolettre_hebdo                      5753740
# onboarding                            2100062
# kit                                    673897
# Contenu                                398288
# ...                                       ...
# admin-media                                 1
# admin-textes-editables                      1
# admin-users                                 1
# admin-objectifs                             1
# thematiques-prendre-soin-de-soi             1
#
# [130 rows x 1 columns]

# %%
df[df.content_type<=1000]
# Out:
#                                  content_type
# Live                                      875
# compte-profil-informations                736
# parcours-id-slug-termine                  718
# ateliers-id-slug                          708
# compte-profil-services                    689
# ...                                       ...
# admin-media                                 1
# admin-textes-editables                      1
# admin-users                                 1
# admin-objectifs                             1
# thematiques-prendre-soin-de-soi             1
#
# [78 rows x 1 columns]

# %%
df[df.content_type<=1000].index.tolist()
# Out:
# ['Live',
#  'compte-profil-informations',
#  'parcours-id-slug-termine',
#  'ateliers-id-slug',
#  'compte-profil-services',
#  'preparer-noel-ecole',
#  'parcours-id-slug',
#  'objectif_cap_rentree_2021-id-slug-difficulte',
#  'compte-profil-favoris',
#  'qui-sommes-nous',
#  'parcours-id-slug-questionnaire-questionnaireId',
#  'histoire-en-maternelle-alma-studio-seance-pedagogique-nougat',
#  'tutos',
#  'contact',
#  'histoire-en-maternelle-alma-studio-seance-pedagogique-gigi-e',
#  'outils-numeriques-enseignants-liste',
#  'compte-droits-insuffisants',
#  'commentaire',
#  'histoire-en-maternelle-alma-studio-seance-pedagogique-peche-',
#  'devenir-mentors',
#  'compte-profil',
#  'objectif_cap_rentree_2021-id-slug-difficulte-contenu-contenu',
#  'admin-contenus-modifier-id',
#  'article',
#  'admin-membres',
#  'objectif_cap_rentree_2021-landing',
#  'outils-numeriques-enseignants-id-slug',
#  'newsletter',
#  'admin-ateliers-modifier-id',
#  'evenement',
#  'compte-profil-abonnement',
#  'compte-quitter',
#  'admin-ateliers',
#  'outils-numeriques-enseignants-accueil',
#  'activite-maternelle-slugDomaineMotcle',
#  'sso-scholavie',
#  'thematiques-gerer-ma-classe-au-quotidien',
#  'guidepratique-dyslexie-recap',
#  'compte-profil-preferences',
#  'compte-profil-services-guides',
#  'histoire-en-maternelle-alma-studio-seance-pedagogique-pitch-',
#  'ÊtrePROF',
#  'fiche-outil',
#  'rentree-kits',
#  'thematiques-preparer-mon-annee',
#  'Page test(Si test Kit sur mon url ma présence est normale)',
#  'rentree-kits-merci-id',
#  'cap-rentree',
#  'admin-contenus',
#  'etreneoprof-slug',
#  'challengers-des-possibles',
#  'admin-guides',
#  'thematiques-enseigner-aussi-a-distance',
#  'education-prioritaire',
#  'tuto',
#  'mes-parcours',
#  'guidepratique-dyslexie',
#  'direction-slug',
#  'histoire-en-maternelle-alma-studio-old',
#  'podcast',
#  'thematiques-remobiliser-les-eleves-desengages',
#  'admin-evenements-modifier-id',
#  'admin-contenus-parcours',
#  'pagetest',
#  'admin-guides-modifier-id',
#  'admin-avis',
#  'admin-membres-modifier-id',
#  'sequence',
#  'admin-pages',
#  'admin-evenements',
#  'admin-contenus-parcours-modifier-id',
#  'rentree',
#  'admin-comparateur',
#  'admin-media',
#  'admin-textes-editables',
#  'admin-users',
#  'admin-objectifs',
#  'thematiques-prendre-soin-de-soi']

# %%
df_interactions.context_id.unique()
# Out:
# array([  nan,  108.,  102., ..., 1036., 1037., 1038.])

# %%
df_interactions.shape
# Out:
# (16675373, 11)

# %% [markdown]
# ### Filter database before joining content

# %%
df_contents.type.unique()
# Out:
# array(['article', 'guide_pratique', 'fiche_outils'], dtype=object)

# %%
df_interactions_filtered = df_interactions[df_interactions.content_type.isin(['contenu', 'guide-pratique', 'fiche-outils'])]

# %%
df_interactions_filtered.shape
# Out:
# (430048, 11)

# %%
df_interactions_filtered = df_interactions_filtered[
    ((df_interactions_filtered.content_type == 'contenu') & (df_interactions_filtered.type == "page_view")) |
    ((df_interactions_filtered.content_type == 'guide-pratique') & (df_interactions_filtered.type == "download")) |
    ((df_interactions_filtered.content_type == 'fiche-outils') & (df_interactions_filtered.type == "download"))
]

# %%
df_interactions_filtered.shape
# Out:
# (423845, 11)

# %% [markdown]
# ## Create `users_content`

# %% [markdown]
# #### Are there some same id for different types ?

# %%
df_contents_lite.columns
# Out:
# Index(['id', 'type', 'transition_ecologique', 'sante_mentale',
#        'ecole_inclusive', 'cps', 'reussite_tous_eleves', 'master_theme'],
#       dtype='object')

# %%
df_contents_lite.groupby('id')['type'].nunique()[df_contents_lite.groupby('id')['type'].nunique() > 1].index.tolist()
# Out:
# []

# %% [markdown]
# **Answer** : No !

# %% [markdown]
# ####

# %%
df_interactions_filtered.columns
# Out:
# Index(['id', 'user_id', 'type', 'content_type', 'content_id', 'context_type',
#        'context_id', 'thema_prio', 'url', 'created_at', 'updated_at'],
#       dtype='object')

# %%
import pandas as pd
from tqdm import tqdm

# 1. CONTENT TYPE FEATURES
# Count interactions by user and content type
content_type_features = df_interactions_filtered.groupby(['user_id', 'content_type']).size().unstack(fill_value=0)
content_type_features.columns = [f'nb_{col.replace("-", "_")}' for col in content_type_features.columns]

# 2. PRIORITY CHALLENGE FEATURES
# Merge with df_contents_lite to get priority challenges and themes
# Fix type mismatch: convert content_id to int to match df_contents_lite id column
df_interactions_filtered['content_id'] = pd.to_numeric(df_interactions_filtered['content_id'], errors='coerce')

df_interactions_with_content = df_interactions_filtered.merge(
    df_contents_lite[['id', 'transition_ecologique', 'sante_mentale', 'ecole_inclusive', 'cps', 'reussite_tous_eleves', 'master_theme']], 
    left_on='content_id', 
    right_on='id', 
    how='left'
)

# Function to count interactions by priority challenge
def count_priority_challenge_interactions(df_merged):
    priority_features = pd.DataFrame(index=df_merged['user_id'].unique())
    priority_features.index.name = 'user_id'  # Ensure index has a name
    
    challenges = ['transition_ecologique', 'sante_mentale', 'ecole_inclusive', 'cps', 'reussite_tous_eleves']
    
    for challenge in tqdm(challenges, desc="Processing priority challenges"):
        # Filter content that matches this challenge (value = 1)
        challenge_interactions = df_merged[df_merged[challenge] == 1]
        
        # Count by user_id
        challenge_counts = challenge_interactions.groupby('user_id').size()
        
        # Add to DataFrame (fill_value=0 for users without interactions on this challenge)
        priority_features[f'nb_{challenge}'] = challenge_counts.reindex(priority_features.index, fill_value=0)
    
    return priority_features.fillna(0).astype(int)

priority_features = count_priority_challenge_interactions(df_interactions_with_content)

# 3. COMBINE INTO FINAL MATRIX
# Start with unique user_ids
df_user_features = pd.DataFrame({'user_id': df_interactions_filtered['user_id'].unique()})

# Merge with content type features
df_user_features = df_user_features.merge(
    content_type_features.reset_index(), 
    on='user_id', 
    how='left'
).fillna(0)

# Merge with priority challenge features
df_user_features = df_user_features.merge(
    priority_features.reset_index(), 
    on='user_id', 
    how='left'
).fillna(0)

# 4. THEME FEATURES
# Filter interactions that have a defined master_theme (not None/NaN)
theme_interactions = df_interactions_with_content.dropna(subset=['master_theme'])

if not theme_interactions.empty:
    # Count interactions by user and theme
    theme_features = theme_interactions.groupby(['user_id', 'master_theme']).size().unstack(fill_value=0)
    theme_features.columns = [f'nb_theme_{col}' for col in theme_features.columns]
    
    # Merge with main matrix
    df_user_features = df_user_features.merge(
        theme_features.reset_index(), 
        on='user_id', 
        how='left'
    ).fillna(0)

# 5. BONUS FEATURES
# Total interactions per user
df_user_features['total_interactions'] = df_interactions_filtered.groupby('user_id').size().values

# Content diversity (number of unique contents consulted)
df_user_features['diversite_contenus'] = df_interactions_filtered.groupby('user_id')['content_id'].nunique().values

# Convert all to integers
numeric_columns = df_user_features.select_dtypes(include=['float64']).columns
df_user_features[numeric_columns] = df_user_features[numeric_columns].astype(int)
# Out:
# Processing priority challenges: 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 35.88it/s]

# %%
df_user_features
# Out:
#        user_id  nb_fiche_outils  nb_guide_pratique  nb_transition_ecologique  \
# 0            1                3                  1                         0
# 1           68             1761                291                        81
# 2         5089                0                  1                         0
# 3        91525                1                  0                         0
# 4        91550                0                  2                         0
# ...        ...              ...                ...                       ...
# 80328   210712                2                  0                         0
# 80329   210714                2                  0                         0
# 80330   210717                2                  0                         0
# 80331   210698                1                  0                         0
# 80332   210720                1                  0                         0
#
#        nb_sante_mentale  nb_ecole_inclusive  nb_cps  nb_reussite_tous_eleves  \
# 0                     0                   0       0                        0
# 1                    68                 169      79                      294
# 2                     0                   0       0                        0
# 3                     0                   0       0                        0
# 4                     0                   0       0                        1
# ...                 ...                 ...     ...                      ...
# 80328                 0                   0       0                        1
# 80329                 0                   0       0                        0
# 80330                 0                   0       0                        0
# 80331                 0                   0       0                        0
# 80332                 0                   0       0                        0
#
#        total_interactions  diversite_contenus
# 0                       4                   4
# 1                      54                  40
# 2                       1                   1
# 3                     103                  67
# 4                       1                   1
# ...                   ...                 ...
# 80328                   1                   1
# 80329                   2                   2
# 80330                   2                   2
# 80331                   2                   2
# 80332                   1                   1
#
# [80333 rows x 10 columns]

# %%
df_user_features.shape
# Out:
# (80333, 10)

# %%
df_contents_lite.columns
# Out:
# Index(['id', 'type', 'transition_ecologique', 'sante_mentale',
#        'ecole_inclusive', 'cps', 'reussite_tous_eleves', 'master_theme'],
#       dtype='object')

# %%
array(['click', 'subscription-ended', 'subscribed',
       'subscription-completed', 'submitted', 'attended', 'download',
       'session', 'connexion', 'inscription', 'contenu_vote',
       'contenu_favoris', 'comment_posted', 'register', 'completed',
       'page_view', 'opened_mail', 'click_mail'], dtype=object)

# %%
# Créer DataFrame avec user_id uniques
df_engagement = pd.DataFrame({'user_id': df_interactions['user_id'].unique()})

# Compter chaque type d'interaction par user
engagement_counts = df_interactions.groupby(['user_id', 'type']).size().unstack(fill_value=0)

# Ajouter seulement les colonnes qui nous intéressent (avec 0 si elles n'existent pas)
df_engagement['nb_vote'] = engagement_counts.get('contenu_vote', 0).values if 'contenu_vote' in engagement_counts.columns else 0
df_engagement['nb_comments'] = engagement_counts.get('comment_posted', 0).values if 'comment_posted' in engagement_counts.columns else 0
df_engagement['nb_opened_mail'] = engagement_counts.get('opened_mail', 0).values if 'opened_mail' in engagement_counts.columns else 0
df_engagement['nb_clicked_mail'] = engagement_counts.get('click_mail', 0).values if 'click_mail' in engagement_counts.columns else 0

# %%
df_engagement
# Out:
#         user_id  nb_vote  nb_comments  nb_opened_mail  nb_clicked_mail
# 0         69952        0            0              77                1
# 1         68886        0            0               1                0
# 2             1        0            0               1                0
# 3            68       31            0             284               12
# 4         70138        0            0             256                0
# ...         ...      ...          ...             ...              ...
# 198932   210716        0            0               0                0
# 198933   210717        0            0               0                0
# 198934   210718        0            0               0                0
# 198935   210719        0            0               0                0
# 198936   210720        0            0               0                0
#
# [198937 rows x 5 columns]

# %%
df_user_features
# Out:
#        user_id  nb_fiche_outils  nb_guide_pratique  nb_transition_ecologique  \
# 0            1                3                  1                         0
# 1           68             1761                291                        81
# 2         5089                0                  1                         0
# 3        91525                1                  0                         0
# 4        91550                0                  2                         0
# ...        ...              ...                ...                       ...
# 80328   210712                2                  0                         0
# 80329   210714                2                  0                         0
# 80330   210717                2                  0                         0
# 80331   210698                1                  0                         0
# 80332   210720                1                  0                         0
#
#        nb_sante_mentale  nb_ecole_inclusive  nb_cps  nb_reussite_tous_eleves  \
# 0                     0                   0       0                        0
# 1                    68                 169      79                      294
# 2                     0                   0       0                        0
# 3                     0                   0       0                        0
# 4                     0                   0       0                        1
# ...                 ...                 ...     ...                      ...
# 80328                 0                   0       0                        1
# 80329                 0                   0       0                        0
# 80330                 0                   0       0                        0
# 80331                 0                   0       0                        0
# 80332                 0                   0       0                        0
#
#        total_interactions  diversite_contenus
# 0                       4                   4
# 1                      54                  40
# 2                       1                   1
# 3                     103                  67
# 4                       1                   1
# ...                   ...                 ...
# 80328                   1                   1
# 80329                   2                   2
# 80330                   2                   2
# 80331                   2                   2
# 80332                   1                   1
#
# [80333 rows x 10 columns]

# %%
print("Colonnes df_engagement:", df_engagement.columns.tolist())
print("Colonnes df_user_features:", df_user_features.columns.tolist())
print("Colonnes communes:", set(df_engagement.columns) & set(df_user_features.columns))
# Out:
# Colonnes df_engagement: ['user_id', 'nb_vote', 'nb_comments', 'nb_opened_mail', 'nb_clicked_mail']
# Colonnes df_user_features: ['user_id', 'nb_fiche_outils', 'nb_guide_pratique', 'nb_transition_ecologique', 'nb_sante_mentale', 'nb_ecole_inclusive', 'nb_cps', 'nb_reussite_tous_eleves', 'total_interactions', 'diversite_contenus']
# Colonnes communes: {'user_id'}

# %%
df_users_featured = df_user_features.merge(
    df_engagement, 
    on='user_id', 
    how='outer'
).fillna(0)

# %%
df_users_featured.shape
# Out:
# (198937, 14)

# %%
df_user_final = pd.read_csv("../data/users_cleaned_and_frequency.csv", low_memory=False)

# %%
df_users_featured.columns
# Out:
# Index(['user_id', 'nb_fiche_outils', 'nb_guide_pratique',
#        'nb_transition_ecologique', 'nb_sante_mentale', 'nb_ecole_inclusive',
#        'nb_cps', 'nb_reussite_tous_eleves', 'total_interactions',
#        'diversite_contenus', 'nb_vote', 'nb_comments', 'nb_opened_mail',
#        'nb_clicked_mail'],
#       dtype='object')

# %%
df_users_featured = df_users_featured.rename(columns={'user_id': 'id'})

# %%
df_users_featured.columns
# Out:
# Index(['id', 'nb_fiche_outils', 'nb_guide_pratique',
#        'nb_transition_ecologique', 'nb_sante_mentale', 'nb_ecole_inclusive',
#        'nb_cps', 'nb_reussite_tous_eleves', 'total_interactions',
#        'diversite_contenus', 'nb_vote', 'nb_comments', 'nb_opened_mail',
#        'nb_clicked_mail'],
#       dtype='object')

# %%
df_user_final.shape
# Out:
# (198889, 71)

# %%
df_user_final.columns
# Out:
# Index(['id', 'statut_infolettre', 'statut_mailchimp', 'code_postal',
#        'departement', 'academie', 'anciennete', 'created_at', 'degre',
#        'maternelle', 'elementaire', 'college', 'lycee', 'lycee_pro', 'autre',
#        'type_etab', 'discipline', 'niveau_tps', 'niveau_ps', 'niveau_ms',
#        'niveau_gs', 'niveau_cp', 'niveau_ce1', 'niveau_ce2', 'niveau_cm1',
#        'niveau_cm2', 'niveau_6e', 'niveau_5e', 'niveau_4e', 'niveau_3e',
#        'niveau_2nde', 'niveau_1ere', 'niveau_terminale', 'niveau_cap',
#        'niveau_bac_pro', 'niveau_post_bac', 'niveau_segpa', 'niveau_ash',
#        'niveau_direction', 'niveau_formateur', 'niveau_documentaliste',
#        'join_date', 'last_action_date', 'total_interactions', 'week_minus_0',
#        'week_minus_1', 'week_minus_2', 'week_minus_3', 'week_minus_4',
#        'week_minus_5', 'week_minus_6', 'week_minus_7', 'week_minus_8',
#        'week_minus_9', 'week_minus_10', 'week_minus_11', 'month_minus_0',
#        'month_minus_1', 'month_minus_2', 'month_minus_3', 'month_minus_4',
#        'month_minus_5', 'month_minus_6', 'month_minus_7', 'month_minus_8',
#        'month_minus_9', 'month_minus_10', 'month_minus_11', 'year_minus_0',
#        'year_minus_1', 'year_minus_2'],
#       dtype='object')

# %%
df_users_featured.shape
# Out:
# (198937, 14)

# %%
df_complete = df_users_featured.merge(
    df_user_final,  
    on='id', 
    how='right'
)

# %%
df_complete.shape
# Out:
# (198889, 84)

# %%
df_complete.columns
# Out:
# Index(['id', 'nb_fiche_outils', 'nb_guide_pratique',
#        'nb_transition_ecologique', 'nb_sante_mentale', 'nb_ecole_inclusive',
#        'nb_cps', 'nb_reussite_tous_eleves', 'total_interactions_x',
#        'diversite_contenus', 'nb_vote', 'nb_comments', 'nb_opened_mail',
#        'nb_clicked_mail', 'statut_infolettre', 'statut_mailchimp',
#        'code_postal', 'departement', 'academie', 'anciennete', 'created_at',
#        'degre', 'maternelle', 'elementaire', 'college', 'lycee', 'lycee_pro',
#        'autre', 'type_etab', 'discipline', 'niveau_tps', 'niveau_ps',
#        'niveau_ms', 'niveau_gs', 'niveau_cp', 'niveau_ce1', 'niveau_ce2',
#        'niveau_cm1', 'niveau_cm2', 'niveau_6e', 'niveau_5e', 'niveau_4e',
#        'niveau_3e', 'niveau_2nde', 'niveau_1ere', 'niveau_terminale',
#        'niveau_cap', 'niveau_bac_pro', 'niveau_post_bac', 'niveau_segpa',
#        'niveau_ash', 'niveau_direction', 'niveau_formateur',
#        'niveau_documentaliste', 'join_date', 'last_action_date',
#        'total_interactions_y', 'week_minus_0', 'week_minus_1', 'week_minus_2',
#        'week_minus_3', 'week_minus_4', 'week_minus_5', 'week_minus_6',
#        'week_minus_7', 'week_minus_8', 'week_minus_9', 'week_minus_10',
#        'week_minus_11', 'month_minus_0', 'month_minus_1', 'month_minus_2',
#        'month_minus_3', 'month_minus_4', 'month_minus_5', 'month_minus_6',
#        'month_minus_7', 'month_minus_8', 'month_minus_9', 'month_minus_10',
#        'month_minus_11', 'year_minus_0', 'year_minus_1', 'year_minus_2'],
#       dtype='object')

# %%
df_complete.to_csv("../data/users_cleaned_with_frequency_engagement_subjects.csv", index=False)
